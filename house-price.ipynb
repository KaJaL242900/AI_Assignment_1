# %%
import pandas as pd

# Create dataset manually
data = {
    'area': [1000, 1200, 1500, 1800, 2000],
    'rooms': [2, 3, 3, 4, 4],
    'age': [10, 5, 8, 2, 1],
    'location': ['A', 'B', 'A', 'B', 'C'],
    'price': [3000000, 4000000, 5000000, 6500000, 7000000]
}

df = pd.DataFrame(data)
df.to_csv("house_data.csv", index=False)

df.head()
# Out:
#    area  rooms  age location    price
# 0  1000      2   10        A  3000000
# 1  1200      3    5        B  4000000
# 2  1500      3    8        A  5000000
# 3  1800      4    2        B  6500000
# 4  2000      4    1        C  7000000

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder

# Encode location
le = LabelEncoder()
df['location'] = le.fit_transform(df['location'])

# Features & target
X = df[['area', 'rooms', 'age', 'location']]
y = df['price']

# Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Model
model = LinearRegression()
model.fit(X_train, y_train)

# Prediction
pred = model.predict(X_test)

print("Predictions:", pred)
# Out:
# Predictions: [6405454.10809925]
